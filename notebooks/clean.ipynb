# %% [markdown]
# # Data Cleaning Notebook
#
# ## Purpose
# This notebook cleans the raw NYC Motor Vehicle Collisions dataset and prepares it for EDA and modeling.
#
# ## Input
# - `Data/raw/Motor_Vehicle_Collisions_-_Crashes_20251209.csv`
# - `Data/clean/nybb_25d/nybb.shp` (NYC borough boundary shapefile for GeoPandas imputation)
#
# ## Output
# - `Data/clean/cleaned_crash_data.csv`
#
# ## Run Order
# This is **Step 1**. Run this notebook before eda.ipynb or any model notebooks.

# %%
import pandas as pd

# %%
BORO_SHAPE = "../Data/clean/nybb_25d/nybb.shp"

# %%
df = pd.read_csv("../Data/raw/Motor_Vehicle_Collisions_-_Crashes_20251209.csv")

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/02/2022       9:20     NaN       NaN        NaN        NaN
# 1  01/02/2022      12:50  QUEENS   11373.0  40.735065  -73.88184
# 2  01/02/2022       0:30     NaN       NaN  40.699190  -73.91469
# 3  01/02/2022       8:44   BRONX   10460.0  40.842224  -73.88776
# 4  01/02/2022       4:15     NaN       NaN  40.743210  -73.89608
#
#                      LOCATION              ON STREET NAME CROSS STREET NAME  \
# 0                         NaN               VANDAM STREET     BORDEN AVENUE
# 1      (40.735065, -73.88184)                GRAND AVENUE  VANKLEECK STREET
# 2       (40.69919, -73.91469)               IRVING AVENUE               NaN
# 3      (40.842224, -73.88776)                         NaN               NaN
# 4       (40.74321, -73.89608)  BROOKLYN QUEENS EXPRESSWAY               NaN
#
#             OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                       NaN  ...                    Unspecified
# 1                       NaN  ...                    Unspecified
# 2                       NaN  ...                            NaN
# 3  1902      MARMION AVENUE  ...                    Unspecified
# 4                       NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4491517                Sedan
# 1                            NaN       4492016                Sedan
# 2                            NaN       4491657                Sedan
# 3                            NaN       4491839                Sedan
# 4                            NaN       4491367                Sedan
#
#                    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0                            Box Truck                  NaN
# 1                                 Bike                  NaN
# 2                                  NaN                  NaN
# 3  Station Wagon/Sport Utility Vehicle                  NaN
# 4                                  NaN                  NaN
#
#   VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370560 entries, 0 to 370559
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH DATE                     370560 non-null  object
#  1   CRASH TIME                     370560 non-null  object
#  2   BOROUGH                        262849 non-null  object
#  3   ZIP CODE                       262797 non-null  float64
#  4   LATITUDE                       346415 non-null  float64
#  5   LONGITUDE                      346415 non-null  float64
#  6   LOCATION                       346415 non-null  object
#  7   ON STREET NAME                 265324 non-null  object
#  8   CROSS STREET NAME              189540 non-null  object
#  9   OFF STREET NAME                105232 non-null  object
#  10  NUMBER OF PERSONS INJURED      370560 non-null  int64
#  11  NUMBER OF PERSONS KILLED       370560 non-null  int64
#  12  NUMBER OF PEDESTRIANS INJURED  370560 non-null  int64
#  13  NUMBER OF PEDESTRIANS KILLED   370560 non-null  int64
#  14  NUMBER OF CYCLIST INJURED      370560 non-null  int64
#  15  NUMBER OF CYCLIST KILLED       370560 non-null  int64
#  16  NUMBER OF MOTORIST INJURED     370560 non-null  int64
#  17  NUMBER OF MOTORIST KILLED      370560 non-null  int64
#  18  CONTRIBUTING FACTOR VEHICLE 1  368059 non-null  object
#  19  CONTRIBUTING FACTOR VEHICLE 2  282802 non-null  object
#  20  CONTRIBUTING FACTOR VEHICLE 3  33476 non-null   object
#  21  CONTRIBUTING FACTOR VEHICLE 4  8804 non-null    object
#  22  CONTRIBUTING FACTOR VEHICLE 5  2633 non-null    object
#  23  COLLISION_ID                   370560 non-null  int64
#  24  VEHICLE TYPE CODE 1            364601 non-null  object
#  25  VEHICLE TYPE CODE 2            245275 non-null  object
#  26  VEHICLE TYPE CODE 3            31070 non-null   object
#  27  VEHICLE TYPE CODE 4            8318 non-null    object
#  28  VEHICLE TYPE CODE 5            2521 non-null    object
# dtypes: float64(3), int64(9), object(17)
# memory usage: 82.0+ MB

# %%
# fix data types for date and time
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], format='%H:%M', errors='coerce')

# %%
df['CRASH DATE'].dtype, df['CRASH TIME'].dtype
# Out:
# (dtype('<M8[ns]'), dtype('<M8[ns]'))

# %%
df['hour'] = df['CRASH TIME'].dt.hour
df['month'] = df['CRASH DATE'].dt.month
df['day_of_week'] = df['CRASH DATE'].dt.dayofweek

# %% [markdown]
# #### a lil sanity check

# %%
df['hour'].isnull().sum(), df['month'].isnull().sum(), df['day_of_week'].isnull().sum()
# Out:
# (np.int64(0), np.int64(0), np.int64(0))

# %%
df['CRASH DATE'].isna().sum(), df['CRASH TIME'].isna().sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df.isnull().sum()
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                          107711
# ZIP CODE                         107763
# LATITUDE                          24145
# LONGITUDE                         24145
# LOCATION                          24145
# ON STREET NAME                   105236
# CROSS STREET NAME                181020
# OFF STREET NAME                  265328
# NUMBER OF PERSONS INJURED             0
# NUMBER OF PERSONS KILLED              0
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      2501
# CONTRIBUTING FACTOR VEHICLE 2     87758
# CONTRIBUTING FACTOR VEHICLE 3    337084
# CONTRIBUTING FACTOR VEHICLE 4    361756
# CONTRIBUTING FACTOR VEHICLE 5    367927
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1                5959
# VEHICLE TYPE CODE 2              125285
# VEHICLE TYPE CODE 3              339490
# VEHICLE TYPE CODE 4              362242
# VEHICLE TYPE CODE 5              368039
# hour                                  0
# month                                 0
# day_of_week                           0
# dtype: int64

# %%
df['BOROUGH'].isnull().sum()
# Out:
# np.int64(107711)

# %%
df[['LATITUDE', 'LONGITUDE']].isnull().sum()
# Out:
# LATITUDE     24145
# LONGITUDE    24145
# dtype: int64

# %%
import geopandas as gpd
from shapely.geometry import Point

# drop rows missing coordinates
df = df.dropna(subset=["LATITUDE", "LONGITUDE"])

# convert to GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df["LONGITUDE"], df["LATITUDE"]),
    crs="EPSG:4326"
)

# load borough boundaries
boros = gpd.read_file(BORO_SHAPE)
boros = boros.to_crs("EPSG:4326")   # match coordinate system

# spatial join: assign each crash a borough based on its coordinates
gdf = gdf.sjoin(boros, how="left", predicate="within")

# look at borough nulls
print(gdf["BoroName"].isna().sum())

gdf.head()
# Out:
# 5557
#   CRASH DATE          CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 1 2022-01-02 1900-01-01 12:50:00  QUEENS   11373.0  40.735065  -73.88184
# 2 2022-01-02 1900-01-01 00:30:00     NaN       NaN  40.699190  -73.91469
# 3 2022-01-02 1900-01-01 08:44:00   BRONX   10460.0  40.842224  -73.88776
# 4 2022-01-02 1900-01-01 04:15:00     NaN       NaN  40.743210  -73.89608
# 6 2022-01-02 1900-01-01 03:00:00     NaN       NaN  40.762940  -73.86067
#
#                      LOCATION              ON STREET NAME CROSS STREET NAME  \
# 1      (40.735065, -73.88184)                GRAND AVENUE  VANKLEECK STREET
# 2       (40.69919, -73.91469)               IRVING AVENUE               NaN
# 3      (40.842224, -73.88776)                         NaN               NaN
# 4       (40.74321, -73.89608)  BROOKLYN QUEENS EXPRESSWAY               NaN
# 6       (40.76294, -73.86067)          GRAND CENTRAL PKWY               NaN
#
#             OFF STREET NAME  ...  VEHICLE TYPE CODE 5  hour  month  \
# 1                       NaN  ...                  NaN    12      1
# 2                       NaN  ...                  NaN     0      1
# 3  1902      MARMION AVENUE  ...                  NaN     8      1
# 4                       NaN  ...                  NaN     4      1
# 6                       NaN  ...                  NaN     3      1
#
#    day_of_week                    geometry  index_right  BoroCode  BoroName  \
# 1            6  POINT (-73.88184 40.73506)          2.0       4.0    Queens
# 2            6  POINT (-73.91469 40.69919)          4.0       3.0  Brooklyn
# 3            6  POINT (-73.88776 40.84222)          1.0       2.0     Bronx
# 4            6  POINT (-73.89608 40.74321)          2.0       4.0    Queens
# 6            6  POINT (-73.86067 40.76294)          2.0       4.0    Queens
#
#       Shape_Leng    Shape_Area
# 1  887905.076135  3.041419e+09
# 2  726953.045036  1.934463e+09
# 3  463147.071763  1.187199e+09
# 4  887905.076135  3.041419e+09
# 6  887905.076135  3.041419e+09
#
# [5 rows x 38 columns]

# %%
df = gdf

# %% [markdown]
# ### note to self
# - The column gets filled **only** gets filled if the crash points lat/lon is inside NYC
# - So technically if `BoroName` is NA then that means the crash coordinate isn't inside NYC polygon. Could be because:
#     - The coordinate is invalid
#     - Coordinate is somewhere outside NYC (like jersey)
# - So basically a missing `BoroName` just means the row is not a valid NYC crash based on location
# - I'll go into this later

# %%
df[['LATITUDE', 'LONGITUDE']].isnull().sum()
# Out:
# LATITUDE     0
# LONGITUDE    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                           87948
# ZIP CODE                          87993
# LATITUDE                              0
# LONGITUDE                             0
# LOCATION                              0
# ON STREET NAME                   102716
# CROSS STREET NAME                167138
# OFF STREET NAME                  243699
# NUMBER OF PERSONS INJURED             0
# NUMBER OF PERSONS KILLED              0
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      2412
# CONTRIBUTING FACTOR VEHICLE 2     82573
# CONTRIBUTING FACTOR VEHICLE 3    315566
# CONTRIBUTING FACTOR VEHICLE 4    338254
# CONTRIBUTING FACTOR VEHICLE 5    343951
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1                5719
# VEHICLE TYPE CODE 2              118118
# VEHICLE TYPE CODE 3              317784
# VEHICLE TYPE CODE 4              338696
# VEHICLE TYPE CODE 5              344053
# hour                                  0
# month                                 0
# day_of_week                           0
# geometry                              0
# index_right                        5557
# BoroCode                           5557
# BoroName                           5557
# Shape_Leng                         5557
# Shape_Area                         5557
# dtype: int64

# %% [markdown]
# ## Documentation of my work so far before continuing
# - I converted raw strings to proper datetime formats for later feature engineering, this enables extraction of hour, month, and day-of-week later.
# - Cleaned the coordinate data
#     - Used official NYC borough boundary shapefile to fill NAs for coordinates and the BOROUGH column (now `BoroName`)
#     - Result: ~5,557 null boroughs
#     - Much fewer than the original 100k+.
# - Decision: Do Not Use Original BOROUGH or ZIP CODE... Based on quality issues:
#     - Original BOROUGH column will not be used
#         - (too many missing values; inconsistent)
#     - ZIP CODE will not be used
#         - (uninformative for modeling, high missingness, unreliable)

# %%
df['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()
# Out:
# CONTRIBUTING FACTOR VEHICLE 1
# Driver Inattention/Distraction                           86066
# Unspecified                                              85719
# Failure to Yield Right-of-Way                            24302
# Following Too Closely                                    19426
# Passing or Lane Usage Improper                           14645
# Unsafe Speed                                             12378
# Passing Too Closely                                      12159
# Backing Unsafely                                         10787
# Other Vehicular                                          10714
# Traffic Control Disregarded                               9816
# Turning Improperly                                        8209
# Driver Inexperience                                       7356
# Unsafe Lane Changing                                      6492
# Alcohol Involvement                                       6452
# Pedestrian/Bicyclist/Other Pedestrian Error/Confusion     4014
# Reaction to Uninvolved Vehicle                            3785
# View Obstructed/Limited                                   3296
# Aggressive Driving/Road Rage                              2952
# Pavement Slippery                                         2234
# Fell Asleep                                               1582
# Oversized Vehicle                                         1379
# Brakes Defective                                          1308
# Passenger Distraction                                     1006
# Outside Car Distraction                                    781
# Steering Failure                                           759
# Lost Consciousness                                         713
# Obstruction/Debris                                         682
# Illnes                                                     608
# Glare                                                      583
# Tire Failure/Inadequate                                    538
# Failure to Keep Right                                      376
# Fatigued/Drowsy                                            369
# Driverless/Runaway Vehicle                                 366
# Pavement Defective                                         359
# Animals Action                                             267
# Drugs (illegal)                                            250
# Accelerator Defective                                      237
# Cell Phone (hand-Held)                                     154
# Traffic Control Device Improper/Non-Working                144
# Physical Disability                                        142
# Lane Marking Improper/Inadequate                           131
# Tinted Windows                                              79
# Tow Hitch Defective                                         48
# Vehicle Vandalism                                           48
# Prescription Medication                                     46
# Other Lighting Defects                                      43
# Eating or Drinking                                          40
# Headlights Defective                                        36
# Using On Board Navigation Device                            32
# Other Electronic Device                                     28
# Cell Phone (hands-free)                                     18
# Windshield Inadequate                                       15
# Shoulders Defective/Improper                                14
# Texting                                                     12
# Listening/Using Headphones                                   8
# Name: count, dtype: int64

# %%
df.keys()
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'hour', 'month', 'day_of_week', 'geometry', 'index_right', 'BoroCode',
#        'BoroName', 'Shape_Leng', 'Shape_Area'],
#       dtype='object')

# %% [markdown]
# ## Next handle cleaning Vehicle type code 1

# %%
df['Type code 1'] = df['VEHICLE TYPE CODE 1'].value_counts()

# %%
df['VEHICLE TYPE CODE 1'].unique()
# Out:
# array(['Sedan', 'Ambulance', 'Station Wagon/Sport Utility Vehicle',
#        'Pick-up Truck', 'Garbage or Refuse', nan, 'Tanker', 'PK',
#        'E-Bike', 'AMBULANCE', 'E-Scooter', 'Motorcycle', 'Bike', 'Taxi',
#        'Box Truck', 'Bus', 'Dump', 'Flat Bed', '3-Door', 'Carry All',
#        'Convertible', 'Pedicab', 'Tractor Truck Diesel', 'Van',
#        'Tractor Truck Gasoline', 'MOTOR SCOO', 'Moped', '4 dr sedan',
#        'Firetruck', 'SELF', 'Snow Plow', 'TRAILER', 'Tow Truck / Wrecker',
#        'Refrigerated Van', 'Motorbike', 'FIRE TRUCK', 'Motorscooter',
#        'School Bus', 'passenger', 'UTILITY', 'Minibike', 'Lunch Wagon',
#        'FIRETRUCK', 'Forklift', 'LIMO', 'Stake or Rack', 'Motorized Home',
#        'DELV', 'Tow Truck', 'Beverage Truck', 'Flat Rack',
#        'Concrete Mixer', 'Chassis Cab', 'Bulk Agriculture', 'unk', 'tr',
#        'Fire truck', 'Truck', 'M2', 'Armored Truck', 'Pas (4dr s', 'Ambu',
#        'moped', 'Delivery', 'Backhoe', 'PICK UP TR', 'Passenger',
#        'USPS small', 'FDNY AMBUL', 'ambulance', 'SUV', '2 dr sedan',
#        '100th truc', 'FOOD CART', 'APP', 'SPR', 'DUMPTRUCK', 'UTIL',
#        'Multi-Wheeled Vehicle', 'Trailer', 'MOPED', 'PAS', 'Garbage Tr',
#        'FIRE', 'fire truck', 'PICKUP', 'SCHOOL BUS', 'AMBU', 'CAT FORKLI',
#        'Postal tru', 'government', 'COMMERCIAL', 'van', 'fork lift',
#        'UNK', 'UPS TRUCK', 'BOX TRUCK', 'Lift Boom', 'FORKLIFT', 'FDNY',
#        'e-scooter', 'TRACTOR', 'NYCHA Van', 'STREET SWE', 'house on w',
#        'Unk', 'USPS VAN', 'MTA BUS', 'PICK UP', 'TRUCK', 'BOBCAT',
#        'FRIEG', 'e bike uni', 'Commercial', 'FDNY FIRE', 'USPCS', 'USPS',
#        'AMB', 'CON ED TRU', 'commercial', 'ROAD SWEEP', 'DUMP',
#        'Livestock Rack', 'Dump truck', 'Lift', 'Utility', 'EMT Ambula',
#        '.', 'TOW TRUCK', 'Sprinter V', 'Open Body', 'TCN', 'ASPHALT RO',
#        'Garbage', 'trailer', 'POWER SHOV', 'VERZION VA', 'SCOOTER',
#        'Self Insur', 'School bus', 'Motorized', 'FREIGHT TR',
#        'FDNY LADER', 'TANK', 'USPS Truck', 'EMS TRUCK', 'AMBULETTE',
#        'scooter', 'Government', 'FDNY Truck',
#        'Pickup with mounted Camper', 'ABULANCE', 'FireTruck', 'Hopper',
#        'Ford', 'PASSENGER', 'backhoe re', 'COMMERICAL', 'F550', 'MACK',
#        'GOVERNMENT', 'USPS TRUCK', 'U-Haul', 'Electric S', 'Scooter',
#        'Pick up', 'USPS posta', 'Pickup', 'FORD', 'UNKNOWN', 'Tractor Tr',
#        'MOPED 150C', 'Ice Cream', 'FEDEX TRUC', 'STAK', 'YW SCHOOL',
#        'MINI VAN', 'F550 ESU R', 'EMS FDNY B', 'SPRINTER V', 'FDNY TRUCK',
#        'SANITATION', 'VAN TRUCK', 'YELLOW TAX', 'FDNY Ladde', 'Tow',
#        'Postal ser', 'MOTORSCOOT', 'Freight', 'SMART', 'NJ transit',
#        'Schoolbus', 'Street Swe', 'usps  van', 'EMS BUS', 'FIRE APPAR',
#        'POSTAL TRU', 'GOVT', 'garbage tr', 'Pallet', 'MINIVAN', 'Amb',
#        'Usps', 'MAIL TRUCK', 'FedEx box', 'MOPAD', 'ELECTRIC S',
#        'City Owned', 'Gas Scoote', 'Road sweep', 'STREET', 'FIRE ENGIN',
#        'Pick Up', 'Fdny engin', 'COM', 'City vehic', 'SELF INSUR',
#        'NYC PARKS', 'GARBAGE TR', 'FORK LIFT', 'Ford picku', 'NYC TRANSI',
#        'USPS truck', 'Fire Truck', 'TRANSIT', 'amb', 'FREIGHTLIN', 'RV',
#        'JETSKI', 'Minicycle', 'Com', 'POLICE VEH', 'box truck',
#        'Well Driller', 'EXCAVATOR', 'Utility ve', '50CC SCOOT', '997',
#        'PSD', 'OTHER', 'NY CITY MT', 'DIRT BIKE', 'Tow truck', '7',
#        'fed ex tru', 'Suv', 'US POSTAL', 'E SCOOTER', 'Sprinter W', 'rmp',
#        'PICK-UP TR', 'In Line Sk', 'PROMASTER', 'Trolley ri', 'Tractor',
#        'E Bike w p', 'COM DELIVE', 'Limousine', 'Mail', 'Fdny ems',
#        'Usps mail', 'CHASSIS &', '999', 'DUMP TRUCK', 'ELE MOTORC',
#        'Gas scoote', 'Self insur', 'FD TRUCK', 'Tractor tr', 'PEPSI DELI',
#        'MAIL CARRI', 'Delivery V', 'Combinatio', 'PASS', '50cc mini',
#        'dirt bike', 'utv', 'UTV', 'SS', 'TL', 'FDNY Ambul', 'Dump Truck',
#        'MOPD', 'power shov', 'TRACTOR TR', 'DELIVERY V', 'Excavator',
#        'MAC', 'Mopped', 'Sweeper', 'bus', 'P PSD', 'FDNY EMS',
#        'DELIVERY T', 'Van Camper', 'unknown', 'Fork Lift', 'UTILITY TR',
#        'RAZOR150 M', 'A,n', 'truck', 'Work truck', 'NYS Ambula',
#        'Fed Ex Tru', 'TRUCK W/TR', 'Delivery T', 'PICK-UP', 'FLATBED TO',
#        'GMC ECOM', 'SUBURBAN', 'REVEL', 'EMS', 'Fire Truvk', 'delivery t',
#        'Commer Veh', 'Fork lift', 'GAS MOPED', 'PETIT CAB', 'MTA Van',
#        'electronic', 'tow', 'Unknown', 'Pickup tru', 'Sanitation', 'tlc',
#        'NYC SANITA', 'MTA', 'electric s', 'VAn', 'Gas Moped', 'Chevy',
#        'NYC FDNY #', 'Scooter ga', 'Waste truc', 'FDNY- Fire',
#        'E MOTORCYC', 'E-SCOOTER', 'SCHOOLBUS', 'Garbage tr', 'BOX CAR',
#        'utility tr', 'Ford Couri', 'TRANSPORT', 'MTA transi',
#        'Electric s', 'Ambulence', 'MOPPED',
#        'Enclosed Body - Nonremovable Enclosure', 'del truck', 'Ford f150',
#        'utv bobcat', 'Van Truck', 'school bus', 'CAN', 'FREIGHT VA',
#        'E-scooter', 'GAS SCOOTE', 'AMBULENCE', 'Dodge ram', 'FORD F-150',
#        'PASSANGER', 'Lim', 'gas moped', 'GOVENMENT', 'BOXTRUCK',
#        'Govt P/U T', 'Rmp', 'DOT', 'FORD AMBUL', 'FDNY FIRET',
#        'FD AMBULAN', 'REG', 'MACK TRUCK', 'HORSE TRAI', 'Grumman LL',
#        'MOOPER', 'Golf cart', 'utility ve', 'Log', 'Sprinter v',
#        'Delivery t', 'USPS VEHIC', 'DOT TRUCK', 'NYC FIRE T', 'commerial',
#        'Pick-Up', 'MINI VAHN', 'VA', 'COMMERICIA', 'street swe',
#        'Ele. Unicy', 'Tank', 'Ford Trans', 'Box truck', 'box van',
#        'E-bike', 'rgs', 'PICKUP TRU', 'Mack truck', 'Electric m',
#        'PEDICAB', 'UNKWOWN', 'USPS #6530', 'LIABITIY', 'UHAUL',
#        'HEAVY TRUC', 'Motor Scoo', 'Road Sweep', 'forklift', 'Crane',
#        'FLYWING MO', 'Small Bus', 'Tk', 'mta bus', 'MANUAL SCO',
#        'Ford FF', 'Traffic To', 'Fdny Fire', 'Ladder', 'Ladder tru',
#        'AMBULANVE', 'ambu', 'Ems truck', 'Vanette', 'MILITARY',
#        'amazon tru', 'MOTORIZEDS', 'ems bus', 'FDNY Vehic', 'YELLOW BUS',
#        'Utility Ve', 'MARKED RMP', 'CRANE', 'DELV WH', 'Pick up Tr',
#        'X Amb', 'SPC', 'MC', 'Limo', 'AMULANCE', 'Subn', 'FDNY truck',
#        'EMI- TRAIL', 'Omnibus', 'Mcy', 'OMS', 'ELECTRIC M', 'pick up tr',
#        'MTA Bus', 'ManPower s', 'NYS AMBULA', 'access-a-r', 'Utility tr',
#        'GOLF CART', 'PASS VAN', 'Pick up tr', 'commerical', 'Pickup tow',
#        '18 WHEELER', 'OMT', 'LSV', 'MTA TRANSI', 'AMBALANCE', 'delv',
#        'Bread truc', 'standing s', 'ELECTRIC C', 'FDNY mecha', 'Courier',
#        'BOOM MOPED', 'METRO TRAN', 'VAN (TRANS', 'GEICO', 'Yale Fork',
#        'Razor Scoo', 'TOW-TRUCK', 'Fire engin', 'Red moped', 'REVEL MOPE',
#        'Street swe', 'Boom Lift', 'Fire Engin', 'HORSE DRAW', 'MOTORHOME',
#        'OMR', 'CAR/SUV', 'mini bus', 'FDNY UTILI', 'WAGON', 'PEDAL BIKE',
#        'Van (Trans', 'BOOM LIFT', 'REF BOX TR', 'UPS truck', 'Mta bus',
#        'GOLFCART', 'rv', 'EMS Bus', 'ONE WHEEL', 'Truck/bus', 'firetruck',
#        'us postal', 'ems truck', 'courier', 'HUMVEE', 'FDNY ambul',
#        'Econoline', 'GARBAGE ST', 'Pvt Ambula', 'Dumb Truck', 'Flatbed',
#        'US MAIL #1', 'CITY OF NE', 'leu', 'TRANSPORTE', 'CONSTRUCTI',
#        'PKUP', '10 Paaseng', 'Electric M', 'E scooter', 'Stand up s',
#        'ALL TERRAI', 'COMM', 'pick', 'Lime Scoot', 'Suburban',
#        'SKATEBOARD', 'moped scoo', 'TRANSIT VA', 'FDNY 245 E',
#        'USPS Mail', 'SUBN/Van', 'subn', 'FDNY EMS#1', 'charter bu',
#        'SELF-INSUR', 'AMBULANE', 'Mail truck', 'nyc', 'Dept Tow t',
#        'Unknown ve', 'Asphalt Pa', 'TRAC', 'Dot', 'FORD TRANS',
#        'COMM TRAIL', 'TRAILER CA', 'Tlc', 'TRLR', 'Bicycle', 'VAGON', '4',
#        'TRUCK/VAN', 'R.M.P.', 'ATTECHMENT', 'SEMI TRUCK', 'Collection',
#        'MOT', 'Bobcat', 'RMP', '4door', 'tow truck', 'NYPD Traff',
#        'TRUCK CRAN', 'van truck', 'Ford EC2', 'Detached t', 'NYFD ambul',
#        'U-HAUL TRU', 'SWEEPER TR', 'MOBILITY S', 'Car carrie',
#        'Gas dirt b', 'Nova', 'Grain', 'Rescue Tru', 'FD Ambulan',
#        'RIV 2022', 'Passanger', 'COT', 'Honda HRV', 'Ebike', 'City Bus',
#        'Food Trail', 'Cargo van', 'FLATBED', 'FREIGT VAN', 'MO-PED',
#        'DELIVERY', 'FDNY INSUR', 'food truck', 'R/V', 'FDNY LADDE',
#        'U-HAUL', 'trk', 'VOLVO', 'Sprinter', 'Usaa', 'GOVERMENT',
#        'Dirt Bike', 'utility', 'Station Wa', 'Standing S', 'AMAZON TRU',
#        'FRONT LOAD', 'X TRL', 'delivery', 'DETACHED T', 'Nissan',
#        'Postal Box', 'WORK VAN', 'FLAT RACK', 'GLBEN', 'CARGO VAN',
#        'EMS -BUS', 'HOUSE ON W', 'Kubota bac', 'MDX', 'Postoffice',
#        'FDNY EMS V', 'PV HOLDING', 'Thomas', 'CEMENT TRU', 'NYC MTA BU',
#        'Yellow sch', 'Fdny Ems T', 'COURIER', 'REN', 'UHaul',
#        'School van', 'Landscapin', 'ECONOLINE', 'Golf Cart', 'Pickup Tru',
#        'SKID STEER', 'MTA bus', 'Motor Home', 'ХР06', 'freightlin',
#        'TRACTOR CR', 'LADDER', 'golf cart', 'Stand Up S', '0000', 'Mixer',
#        'Ambulances', 'RAZOR SCOO', 'FDNY VEHIC', 'G', 'ACCESS A R',
#        'Bearcat', 'LAWN MOWER', 'sanitation', 'X AMB', 'one wheel',
#        'Yellow Cab', 'MOVING TRU', 'Piggy back', 'Bulldozer', 'UNICYCLE',
#        'd1', 'VAN BUS', 'd', 'FDNY EMS v', 'fdny firet', 'DELIVRY TR',
#        'SW/SUV', 'tank', 'Tralier', 'EMS bus', 'Old republ', 'Standing s',
#        'Mercedes', 'KW', 'Skid steer', '5', 'Fuso', 'Mini Van',
#        'FUSO TRUCK', 'G PSD', 'LADDER 169', 'SCHOO LBUS', 'PROGRESSIV',
#        '4dsd', 'X COM', 'Power Shov', 'PLOW', 'c1', 'US Postal',
#        'Yellow bus', 'HOVERBOARD', 'Surburban', 'Toolcat', 'TRL',
#        'Amazon del', 'For', 'DOLLAR VAN', 'FDNY ENGIN', 'G AMB',
#        'EMS FDNY', 'Engine 26', 'pas', 'YELLOWSCHO', 'USPS DELIV',
#        'FDNYTRUCKF', 'two wheel', 'MARKED VAN', 'a', 'SENIORCARE',
#        'JOHN DEERE', 'Motor scoo', 'tractor tr', 'RD/S', 'COURIER VA',
#        'Panel Van', 'Trolley', 'Small scho', 'PSVAN', 'volks',
#        'Usps truck', 'Rec Vehicl', 'Macktruck', 'MTA BUS CO', 'A',
#        'Fdny fire', 'WINNIEBAGO', 'HOSRE DRAW', 'DOS TRUCK', 'DUMP TRUK',
#        'trk-m1', 'Citi bike', 'FDNY Fire', 'NYC School', 'BLACK SCOO',
#        'taxi', 'NINEBOT', 'seated sco', 'fdny ambul', 'Electric B',
#        'Flatbed Tr', 'FIRE LADDE', '18 wheeler', 'TANK TRUCK',
#        'DSNY SWEEP', 'Escooter', 'MOTOR UNIC', 'vAN', 'E-BIKE',
#        'Box Trucki', 'GATOR', 'Ford Pick', 'AMAZON VAN', 'FARM VEHIC',
#        'Quadricycl', 'FOOD TRUCK', 'Ice cream', 'MERCEDES', 'SCOOTOR',
#        'E bike', 'sweeper', 'NYPD TOW T', 'SPRINTER', 'EMS Truck',
#        'White subu', 'COMMMERICA', 'TOUR', 'cadil', 'Ambulette',
#        'AMBULANCE`', 'COMERCIAL', 'VERIZON TR', 'H Carriage',
#        'sprinter v', 'EMS Ambule', 'YELLOWBUS', 'g2', 'RAM', 'TRAILER VE',
#        'NYS insura', 'ACCESS-ARI', 'DOT truck', 'postal tru', 'Unkown',
#        'Cement tru', 'TOY MINI V', 'h1', 'PICK-UP F-', 'Forklift v',
#        'trac', 'ACCESS RID', 'Gmc pick u', 'FDNY FERRA', 'EMS AMBULA',
#        'USPS van', 'Pas', 'CITY TRUCK', 'NYPD towtr', 'MEDALLION',
#        'FDNY ENG.', 'SWEEPER', 'DSNY', 'yellow bus', 'OML', 'tow-truck',
#        'st clean t', 'SEDAN', 'fdny', 'Pick Up Tr', 'STATE FARM'],
#       dtype=object)

# %%
df['Type code 1 lower'] = df['VEHICLE TYPE CODE 1'].str.lower()

# %%
counts = df['Type code 1 lower'].value_counts()

# %%
df['count vehicles'] = df['Type code 1 lower'].map(counts)

# %%
df[['VEHICLE TYPE CODE 1', 'Type code 1 lower', 'count vehicles']]
# Out:
#                         VEHICLE TYPE CODE 1  \
# 1                                     Sedan
# 2                                     Sedan
# 3                                     Sedan
# 4                                     Sedan
# 6                                 Ambulance
# ...                                     ...
# 370554                                Sedan
# 370555  Station Wagon/Sport Utility Vehicle
# 370557                                Sedan
# 370558                                  Bus
# 370559  Station Wagon/Sport Utility Vehicle
#
#                           Type code 1 lower  count vehicles
# 1                                     sedan        158471.0
# 2                                     sedan        158471.0
# 3                                     sedan        158471.0
# 4                                     sedan        158471.0
# 6                                 ambulance          2321.0
# ...                                     ...             ...
# 370554                                sedan        158471.0
# 370555  station wagon/sport utility vehicle        119145.0
# 370557                                sedan        158471.0
# 370558                                  bus          6603.0
# 370559  station wagon/sport utility vehicle        119145.0
#
# [346415 rows x 3 columns]

# %%
df['count vehicles'].describe()
# Out:
# count    340696.000000
# mean     116312.915784
# std       55886.006203
# min           1.000000
# 25%      119145.000000
# 50%      119145.000000
# 75%      158471.000000
# max      158471.000000
# Name: count vehicles, dtype: float64

# %%
df['veh_type'] = df['VEHICLE TYPE CODE 1'].str.lower().str.strip()

# %%
# look at the most common 
df['veh_type'].value_counts().head(25)
# Out:
# veh_type
# sedan                                  158471
# station wagon/sport utility vehicle    119145
# taxi                                     9636
# pick-up truck                            7921
# bus                                      6603
# bike                                     6379
# box truck                                5535
# motorcycle                               3416
# e-bike                                   2843
# moped                                    2452
# ambulance                                2321
# tractor truck diesel                     2287
# van                                      2088
# e-scooter                                1690
# dump                                     1112
# convertible                               862
# pk                                        860
# garbage or refuse                         775
# flat bed                                  566
# carry all                                 404
# tow truck / wrecker                       403
# tractor truck gasoline                    341
# motorscooter                              332
# standing s                                330
# chassis cab                               277
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

df['veh_type'].unique()
# Out:
# array(['sedan', 'ambulance', 'station wagon/sport utility vehicle',
#        'pick-up truck', 'garbage or refuse', nan, 'tanker', 'pk',
#        'e-bike', 'e-scooter', 'motorcycle', 'bike', 'taxi', 'box truck',
#        'bus', 'dump', 'flat bed', '3-door', 'carry all', 'convertible',
#        'pedicab', 'tractor truck diesel', 'van', 'tractor truck gasoline',
#        'motor scoo', 'moped', '4 dr sedan', 'firetruck', 'self',
#        'snow plow', 'trailer', 'tow truck / wrecker', 'refrigerated van',
#        'motorbike', 'fire truck', 'motorscooter', 'school bus',
#        'passenger', 'utility', 'minibike', 'lunch wagon', 'forklift',
#        'limo', 'stake or rack', 'motorized home', 'delv', 'tow truck',
#        'beverage truck', 'flat rack', 'concrete mixer', 'chassis cab',
#        'bulk agriculture', 'unk', 'tr', 'truck', 'm2', 'armored truck',
#        'pas (4dr s', 'ambu', 'delivery', 'backhoe', 'pick up tr',
#        'usps small', 'fdny ambul', 'suv', '2 dr sedan', '100th truc',
#        'food cart', 'app', 'spr', 'dumptruck', 'util',
#        'multi-wheeled vehicle', 'pas', 'garbage tr', 'fire', 'pickup',
#        'cat forkli', 'postal tru', 'government', 'commercial',
#        'fork lift', 'ups truck', 'lift boom', 'fdny', 'tractor',
#        'nycha van', 'street swe', 'house on w', 'usps van', 'mta bus',
#        'pick up', 'bobcat', 'frieg', 'e bike uni', 'fdny fire', 'uspcs',
#        'usps', 'amb', 'con ed tru', 'road sweep', 'livestock rack',
#        'dump truck', 'lift', 'emt ambula', '.', 'sprinter v', 'open body',
#        'tcn', 'asphalt ro', 'garbage', 'power shov', 'verzion va',
#        'scooter', 'self insur', 'motorized', 'freight tr', 'fdny lader',
#        'tank', 'usps truck', 'ems truck', 'ambulette', 'fdny truck',
#        'pickup with mounted camper', 'abulance', 'hopper', 'ford',
#        'backhoe re', 'commerical', 'f550', 'mack', 'u-haul', 'electric s',
#        'usps posta', 'unknown', 'tractor tr', 'moped 150c', 'ice cream',
#        'fedex truc', 'stak', 'yw school', 'mini van', 'f550 esu r',
#        'ems fdny b', 'sanitation', 'van truck', 'yellow tax',
#        'fdny ladde', 'tow', 'postal ser', 'motorscoot', 'freight',
#        'smart', 'nj transit', 'schoolbus', 'usps  van', 'ems bus',
#        'fire appar', 'govt', 'pallet', 'minivan', 'mail truck',
#        'fedex box', 'mopad', 'city owned', 'gas scoote', 'street',
#        'fire engin', 'fdny engin', 'com', 'city vehic', 'nyc parks',
#        'ford picku', 'nyc transi', 'transit', 'freightlin', 'rv',
#        'jetski', 'minicycle', 'police veh', 'well driller', 'excavator',
#        'utility ve', '50cc scoot', '997', 'psd', 'other', 'ny city mt',
#        'dirt bike', '7', 'fed ex tru', 'us postal', 'e scooter',
#        'sprinter w', 'rmp', 'pick-up tr', 'in line sk', 'promaster',
#        'trolley ri', 'e bike w p', 'com delive', 'limousine', 'mail',
#        'fdny ems', 'usps mail', 'chassis &', '999', 'ele motorc',
#        'fd truck', 'pepsi deli', 'mail carri', 'delivery v', 'combinatio',
#        'pass', '50cc mini', 'utv', 'ss', 'tl', 'mopd', 'mac', 'mopped',
#        'sweeper', 'p psd', 'delivery t', 'van camper', 'utility tr',
#        'razor150 m', 'a,n', 'work truck', 'nys ambula', 'truck w/tr',
#        'pick-up', 'flatbed to', 'gmc ecom', 'suburban', 'revel', 'ems',
#        'fire truvk', 'commer veh', 'gas moped', 'petit cab', 'mta van',
#        'electronic', 'pickup tru', 'tlc', 'nyc sanita', 'mta', 'chevy',
#        'nyc fdny #', 'scooter ga', 'waste truc', 'fdny- fire',
#        'e motorcyc', 'box car', 'ford couri', 'transport', 'mta transi',
#        'ambulence', 'enclosed body - nonremovable enclosure', 'del truck',
#        'ford f150', 'utv bobcat', 'can', 'freight va', 'dodge ram',
#        'ford f-150', 'passanger', 'lim', 'govenment', 'boxtruck',
#        'govt p/u t', 'dot', 'ford ambul', 'fdny firet', 'fd ambulan',
#        'reg', 'mack truck', 'horse trai', 'grumman ll', 'mooper',
#        'golf cart', 'log', 'usps vehic', 'dot truck', 'nyc fire t',
#        'commerial', 'mini vahn', 'va', 'commericia', 'ele. unicy',
#        'ford trans', 'box van', 'rgs', 'electric m', 'unkwown',
#        'usps #6530', 'liabitiy', 'uhaul', 'heavy truc', 'crane',
#        'flywing mo', 'small bus', 'tk', 'manual sco', 'ford ff',
#        'traffic to', 'ladder', 'ladder tru', 'ambulanve', 'vanette',
#        'military', 'amazon tru', 'motorizeds', 'fdny vehic', 'yellow bus',
#        'marked rmp', 'delv wh', 'x amb', 'spc', 'mc', 'amulance', 'subn',
#        'emi- trail', 'omnibus', 'mcy', 'oms', 'manpower s', 'access-a-r',
#        'pass van', 'pickup tow', '18 wheeler', 'omt', 'lsv', 'ambalance',
#        'bread truc', 'standing s', 'electric c', 'fdny mecha', 'courier',
#        'boom moped', 'metro tran', 'van (trans', 'geico', 'yale fork',
#        'razor scoo', 'tow-truck', 'red moped', 'revel mope', 'boom lift',
#        'horse draw', 'motorhome', 'omr', 'car/suv', 'mini bus',
#        'fdny utili', 'wagon', 'pedal bike', 'ref box tr', 'golfcart',
#        'one wheel', 'truck/bus', 'humvee', 'econoline', 'garbage st',
#        'pvt ambula', 'dumb truck', 'flatbed', 'us mail #1', 'city of ne',
#        'leu', 'transporte', 'constructi', 'pkup', '10 paaseng',
#        'stand up s', 'all terrai', 'comm', 'pick', 'lime scoot',
#        'skateboard', 'moped scoo', 'transit va', 'fdny 245 e', 'subn/van',
#        'fdny ems#1', 'charter bu', 'self-insur', 'ambulane', 'nyc',
#        'dept tow t', 'unknown ve', 'asphalt pa', 'trac', 'comm trail',
#        'trailer ca', 'trlr', 'bicycle', 'vagon', '4', 'truck/van',
#        'r.m.p.', 'attechment', 'semi truck', 'collection', 'mot', '4door',
#        'nypd traff', 'truck cran', 'ford ec2', 'detached t', 'nyfd ambul',
#        'u-haul tru', 'sweeper tr', 'mobility s', 'car carrie',
#        'gas dirt b', 'nova', 'grain', 'rescue tru', 'riv 2022', 'cot',
#        'honda hrv', 'ebike', 'city bus', 'food trail', 'cargo van',
#        'freigt van', 'mo-ped', 'fdny insur', 'food truck', 'r/v', 'trk',
#        'volvo', 'sprinter', 'usaa', 'goverment', 'station wa',
#        'front load', 'x trl', 'nissan', 'postal box', 'work van', 'glben',
#        'ems -bus', 'kubota bac', 'mdx', 'postoffice', 'fdny ems v',
#        'pv holding', 'thomas', 'cement tru', 'nyc mta bu', 'yellow sch',
#        'fdny ems t', 'ren', 'school van', 'landscapin', 'skid steer',
#        'motor home', 'хр06', 'tractor cr', '0000', 'mixer', 'ambulances',
#        'g', 'access a r', 'bearcat', 'lawn mower', 'yellow cab',
#        'moving tru', 'piggy back', 'bulldozer', 'unicycle', 'd1',
#        'van bus', 'd', 'delivry tr', 'sw/suv', 'tralier', 'old republ',
#        'mercedes', 'kw', '5', 'fuso', 'fuso truck', 'g psd', 'ladder 169',
#        'schoo lbus', 'progressiv', '4dsd', 'x com', 'plow', 'c1',
#        'hoverboard', 'surburban', 'toolcat', 'trl', 'amazon del', 'for',
#        'dollar van', 'g amb', 'ems fdny', 'engine 26', 'yellowscho',
#        'usps deliv', 'fdnytruckf', 'two wheel', 'marked van', 'a',
#        'seniorcare', 'john deere', 'rd/s', 'courier va', 'panel van',
#        'trolley', 'small scho', 'psvan', 'volks', 'rec vehicl',
#        'macktruck', 'mta bus co', 'winniebago', 'hosre draw', 'dos truck',
#        'dump truk', 'trk-m1', 'citi bike', 'nyc school', 'black scoo',
#        'ninebot', 'seated sco', 'electric b', 'flatbed tr', 'fire ladde',
#        'tank truck', 'dsny sweep', 'escooter', 'motor unic', 'box trucki',
#        'gator', 'ford pick', 'amazon van', 'farm vehic', 'quadricycl',
#        'scootor', 'e bike', 'nypd tow t', 'white subu', 'commmerica',
#        'tour', 'cadil', 'ambulance`', 'comercial', 'verizon tr',
#        'h carriage', 'ems ambule', 'yellowbus', 'g2', 'ram', 'trailer ve',
#        'nys insura', 'access-ari', 'unkown', 'toy mini v', 'h1',
#        'pick-up f-', 'forklift v', 'access rid', 'gmc pick u',
#        'fdny ferra', 'ems ambula', 'city truck', 'nypd towtr',
#        'medallion', 'fdny eng.', 'dsny', 'oml', 'st clean t',
#        'state farm'], dtype=object)

# %% [markdown]
# ##### Note to self
# - I clicked open in a text editor and what in the world.. ![image.png](attachment:image.png)

# %%
def categorize_vehicle(x):
    if pd.isna(x):
        return 'other'
    
    if 'sedan' in x:
        return 'sedan'
    if 'suv' in x or 'station wagon' in x:
        return 'suv'
    if 'taxi' in x or 'cab' in x:
        return 'taxi'
    if 'bus' in x:
        return 'bus'
    if 'bike' in x or 'bicycle' in x:
        return 'bike'
    if 'motor' in x or 'moped' in x or 'scooter' in x or 'cycle' in x:
        return 'motorcycle'
    if 'van' in x:
        return 'van'
    if ('truck' in x or 'trk' in x or 'pick' in x or 'flatbed' in x 
        or 'box truck' in x or 'tractor' in x or 'dump' in x):
        return 'truck'
    
    return 'other'

# %%
df['veh_group'] = df['veh_type'].apply(categorize_vehicle)

# %%
df['veh_group'].value_counts()
# Out:
# veh_group
# sedan         158566
# suv           119157
# truck          18223
# other          14133
# taxi            9957
# bike            9458
# motorcycle      7991
# bus             6737
# van             2193
# Name: count, dtype: int64

# %% [markdown]
# ## docoumentation for cleaning Vehicle type 1 column
# ### The reasoning
# - The raw VEHICLE TYPE CODE 1 column contained over 800 unique values, including:
#     - typos
#     - abbreviations
#     - agency vehicle types (FDNY, USPS, MTA, NYPD)
#     - equipment (forklifts, bulldozers, cranes)
#     - extremely specific truck types
#     - scooters, mopeds, dirt bikes, bikes
#     - garbage trucks, delivery vans
#     - and many inconsistent variations (“pick-up truck”, “pick up tr”, “pickup”, “pick-up f-”, etc.)
# - This level of granularity is not useful for modeling pedestrian injury risk and is not interpretable for Vision Zero stakeholders.
# - Therefore, we generalized all vehicle types into meaningful, safety-focused groups.
#
# ##### Steps
# - First we converted vehicle type strings to lowercase and stripped whitespace and this reduced variation caused by casing and spacing but did not fix inconsistencies which is expected.
# - Next we inspected the full list of unique entries... This confirmed that the raw data included:
#     - duplicate categories with minor spelling differences
#     - dozens of truck variations
#     - multiple scooter/moped/motorcycle forms
#     - unusual entries (e.g., “horse draw”, “lawn mower”, “house on w”)
#     - many agency-specific vehicles
#     - several “unknown” types
#         - This justified the need for categorical generalization.
# - When I looked at this column, there were literally 800+ random vehicle types. Half of them were typos, super specific versions of the same thing, or agency vehicles like FDNY ladders, USPS vans, forklifts, etc. There’s no way this level of detail is useful for modeling or for Vision Zero, and trying to clean every single one would just make things messy, it would introduce noise and it's time consuming. So instead, I grouped everything into broad categories that actually matter for pedestrian safety, like sedan, SUV, truck, taxi, bike, motorcycle, van, and bus. These categories show the real differences in risk, and they keep the model easy to interpret. The point isn’t to perfectly fix every label, it’s to make the data meaningful, clean, and something a stakeholder can actually use. So generalizing was the smartest and cleanest way to handle this column.

# %% [markdown]
# ### Further cleaning regarding lat and lon

# %%
boros.total_bounds # GeoPandas function that tells you the exact geographic bounding box of your shapefile... epic
# Out:
# array([-74.25559136,  40.49613399, -73.70000906,  40.91553278])

# %%
# check for invalid or outside nyc coordinates
invalid_lat = (df['LATITUDE'] < 40) | (df['LATITUDE'] > 41)
invalid_lon = (df['LONGITUDE'] < -74.3) | (df['LONGITUDE'] > -73.3)

invalid_total = df[invalid_lat | invalid_lon]

len(invalid_total)
# Out:
# 4479

# %%
df[invalid_lon].shape[0]
# Out:
# 4479

# %%
df[invalid_lat].shape[0]
# Out:
# 4479

# %%
gdf = gdf[(gdf['LATITUDE'] > 35) & (gdf['LATITUDE'] < 46)]
gdf = gdf[(gdf['LONGITUDE'] < -70) & (gdf['LONGITUDE'] > -80)]

# %%
df.keys()
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'hour', 'month', 'day_of_week', 'geometry', 'index_right', 'BoroCode',
#        'BoroName', 'Shape_Leng', 'Shape_Area', 'Type code 1',
#        'Type code 1 lower', 'count vehicles', 'veh_type', 'veh_group'],
#       dtype='object')

# %%
gdf[['LATITUDE', 'LONGITUDE', 'BoroName']].head()
# Out:
#     LATITUDE  LONGITUDE  BoroName
# 1  40.735065  -73.88184    Queens
# 2  40.699190  -73.91469  Brooklyn
# 3  40.842224  -73.88776     Bronx
# 4  40.743210  -73.89608    Queens
# 6  40.762940  -73.86067    Queens

# %%
missing_boros = gdf[gdf['BoroName'].isnull()]
missing_boros.shape
# Out:
# (1078, 43)

# %%
points_near_boundry = missing_boros.plot()
boros.plot(ax=points_near_boundry)
# Out:
# <Axes: >

# %%
base = boros.plot(color = 'blue')
missing_boros.plot(ax=base, marker='o', color='red', markersize=5)
# Out:
# <Axes: >

# %%
missing_boros[['LATITUDE', 'LONGITUDE', 'BoroName']].head()
# Out:
#        LATITUDE  LONGITUDE BoroName
# 286   40.622414 -73.896484      NaN
# 2348  40.797737 -73.826990      NaN
# 2932  40.727870 -73.929130      NaN
# 3239  40.845352 -73.928210      NaN
# 3276  40.758340 -73.957750      NaN

# %% [markdown]
# ### yap documentation... in simple terms
# - What is a polygon?
#      - it's a shape drawn on a map, it covers an area with edges and corners
#         - Like the outline of manhattan, brooklyn, queens and so on
#         - So saying "brooklyn polygon" refers to the official drawn shape that represents Brooklyn on the map
# - In this context, a point refers to a location in NYC with a single lat and long
#     - So the points represent where the crash happened and it's exact spot
# - The question is why do some points get a borough, whilst others get NaN?
#     - if the point is inside a polygon -> it gets a borough name
#     - if the point is outside all polygons -> it'll get an NaN
#         - This includes points in water (also known as water polygon), points on bridges, points exactly on boundry lines
#
# - I can drop these NaN's because borderline points add noise, not insight

# %%
gdf = gdf[gdf['BoroName'].notna()]

# %%
# sanity check for na's in boroughs
gdf['BoroName'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### lets clean up aile 5... aka the outliers
# - I think these are important findings, these extreme cases can reveal systemic risks or dangerous intersections, speeding corridors or maybe a lighting or road design issues
# - the presence of VEHICLE TYPE CODE 5 (5 vehicles) explains the high injury counts. These rows are NOT errors and should NOT be dropped. They represent serious crashes and are extremely valuable to your analysis.

# %%
df.keys()
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'hour', 'month', 'day_of_week', 'geometry', 'index_right', 'BoroCode',
#        'BoroName', 'Shape_Leng', 'Shape_Area', 'Type code 1',
#        'Type code 1 lower', 'count vehicles', 'veh_type', 'veh_group'],
#       dtype='object')

# %%
df[['NUMBER OF PERSONS INJURED',
       'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
       'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
       'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
       'NUMBER OF MOTORIST KILLED']].describe()
# Out:
#        NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# count              346415.000000             346415.000000
# mean                    0.552811                  0.002685
# std                     0.838572                  0.054303
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     1.000000                  0.000000
# max                    34.000000                  4.000000
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# count                  346415.000000                 346415.000000
# mean                        0.099525                      0.001250
# std                         0.316867                      0.036458
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                        19.000000                      4.000000
#
#        NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# count              346415.000000             346415.000000
# mean                    0.056092                  0.000254
# std                     0.234264                  0.015936
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     3.000000                  1.000000
#
#        NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED
# count               346415.000000              346415.000000
# mean                     0.375218                   0.001039
# std                      0.814789                   0.034804
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                     34.000000                   3.000000

# %%
df[df['NUMBER OF PERSONS INJURED'] > 30]
# Out:
#        CRASH DATE          CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 127763 2023-04-07 1900-01-01 22:24:00  QUEENS   11361.0  40.75958  -73.76894
#
#                          LOCATION  ON STREET NAME CROSS STREET NAME  \
# 127763      (40.75958, -73.76894)  BELL BOULEVARD           45 ROAD
#
#        OFF STREET NAME  ...  index_right  BoroCode  BoroName     Shape_Leng  \
# 127763             NaN  ...          2.0       4.0    Queens  887905.076135
#
#           Shape_Area  Type code 1  Type code 1 lower  count vehicles veh_type  \
# 127763  3.041419e+09          NaN                bus          6603.0      bus
#
#        veh_group
# 127763       bus
#
# [1 rows x 43 columns]

# %%
# df[(df['NUMBER OF PERSONS INJURED'] > 30) & (df['NUMBER OF PERSONS INJURED'] < 40)]

# %%
# df[(df['NUMBER OF PERSONS INJURED'] > 10) & (df['NUMBER OF PERSONS INJURED'] < 20)]

# %%
vehicle_cols = [
    'VEHICLE TYPE CODE 1',
    'VEHICLE TYPE CODE 2',
    'VEHICLE TYPE CODE 3',
    'VEHICLE TYPE CODE 4',
    'VEHICLE TYPE CODE 5'
]

df['num_vehicles'] = df[vehicle_cols].notna().sum(axis=1)
df['num_vehicles'].value_counts()
# Out:
# num_vehicles
# 2    199665
# 1    112401
# 3     20912
# 0      5718
# 4      5357
# 5      2362
# Name: count, dtype: int64

# %%
'veh_type' in df.columns
# Out:
# True

# %%
gdf['veh_type'] = df['veh_type']
gdf['num_vehicles'] = df['num_vehicles']

# %%
df[df['NUMBER OF PERSONS INJURED'] > 10][[
    'NUMBER OF PERSONS INJURED',
    'num_vehicles',
    'veh_type'
]]
# Out:
#         NUMBER OF PERSONS INJURED  num_vehicles  \
# 16842                          13             3
# 37848                          13             2
# 40815                          15             2
# 54634                          14             2
# 61289                          13             1
# 67414                          15             2
# 87229                          11             3
# 88062                          11             2
# 104063                         21             1
# 119439                         11             2
# 122262                         23             2
# 127763                         34             2
# 133046                         13             2
# 135530                         13             2
# 138614                         11             2
# 141910                         15             4
# 148965                         13             2
# 152061                         12             2
# 152404                         18             2
# 153902                         17             2
# 157188                         11             5
# 157873                         15             2
# 158858                         13             1
# 159410                         12             4
# 161824                         13             2
# 164252                         11             5
# 196302                         13             3
# 196349                         11             2
# 197365                         12             2
# 199504                         25             5
# 207082                         11             2
# 214068                         15             4
# 215451                         15             4
# 221906                         12             3
# 225880                         15             2
# 242542                         15             2
# 246434                         11             3
# 254483                         12             1
# 273956                         17             5
# 284725                         11             2
# 294798                         13             2
# 297706                         12             2
# 306472                         17             2
# 319546                         20             2
# 325945                         11             5
# 333017                         13             1
# 339280                         14             1
# 341277                         15             1
# 344184                         11             5
# 357994                         20             2
# 360224                         11             2
# 360621                         11             5
#
#                                    veh_type
# 16842                                   bus
# 37848   station wagon/sport utility vehicle
# 40815                                   bus
# 54634                             box truck
# 61289                                   bus
# 67414                                   bus
# 87229                                   bus
# 88062                                   bus
# 104063  station wagon/sport utility vehicle
# 119439                                  bus
# 122262  station wagon/sport utility vehicle
# 127763                                  bus
# 133046  station wagon/sport utility vehicle
# 135530                            box truck
# 138614                                  bus
# 141910                                sedan
# 148965                                  bus
# 152061                                  bus
# 152404                                  bus
# 153902                            ambulance
# 157188                                sedan
# 157873                                  bus
# 158858                                 limo
# 159410                                 taxi
# 161824                                  bus
# 164252  station wagon/sport utility vehicle
# 196302                                  bus
# 196349                                  van
# 197365                    garbage or refuse
# 199504                            box truck
# 207082                                  bus
# 214068                        pick-up truck
# 215451  station wagon/sport utility vehicle
# 221906  station wagon/sport utility vehicle
# 225880                                  van
# 242542                                  bus
# 246434  station wagon/sport utility vehicle
# 254483                                  bus
# 273956  station wagon/sport utility vehicle
# 284725                                  bus
# 294798                                sedan
# 297706                                  bus
# 306472                                sedan
# 319546                                  bus
# 325945                            carry all
# 333017                                  bus
# 339280                                  bus
# 341277  station wagon/sport utility vehicle
# 344184                                sedan
# 357994                                  bus
# 360224  station wagon/sport utility vehicle
# 360621                                 taxi

# %% [markdown]
# ### note
# During cleaning, we examined rows where more than 10 people were injured. Most of these involved buses, trucks, or SUVs, which is realistic because these vehicles carry many passengers. The number of vehicles involved was consistent with the severity of the crash, so we kept these rows instead of treating them as outliers.

# %%
df[df['NUMBER OF PERSONS INJURED'] > 10].groupby('veh_type').size().sort_values(ascending=False)
# Out:
# veh_type
# bus                                    24
# station wagon/sport utility vehicle    11
# sedan                                   5
# box truck                               3
# taxi                                    2
# van                                     2
# ambulance                               1
# carry all                               1
# garbage or refuse                       1
# limo                                    1
# pick-up truck                           1
# dtype: int64

# %%
df['NUMBER OF PEDESTRIANS INJURED'].describe()
# Out:
# count    346415.000000
# mean          0.099525
# std           0.316867
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          19.000000
# Name: NUMBER OF PEDESTRIANS INJURED, dtype: float64

# %%
df[df['NUMBER OF PEDESTRIANS INJURED'] > 5]
# Out:
#        CRASH DATE          CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 104063 2023-01-02 1900-01-01 20:59:00        NaN       NaN  40.867012
# 159410 2023-08-01 1900-01-01 17:35:00  MANHATTAN   10168.0  40.751442
# 164818 2023-08-21 1900-01-01 02:00:00  MANHATTAN   10018.0  40.751080
# 246692 2024-07-04 1900-01-01 20:52:00  MANHATTAN   10002.0  40.711533
# 290041 2024-12-25 1900-01-01 16:00:00  MANHATTAN   10001.0  40.749790
# 333531 2025-07-03 1900-01-01 10:50:00      BRONX   10451.0  40.816555
# 359475 2025-10-20 1900-01-01 15:55:00  MANHATTAN   10001.0  40.749363
#
#         LONGITUDE                    LOCATION          ON STREET NAME  \
# 104063  -73.92312      (40.867012, -73.92312)                BROADWAY
# 159410  -73.97606      (40.751442, -73.97606)        LEXINGTON AVENUE
# 164818  -73.98686       (40.75108, -73.98686)  AVENUE OF THE AMERICAS
# 246692  -73.98063      (40.711533, -73.98063)            WATER STREET
# 290041  -73.98777       (40.74979, -73.98777)                 W 34 ST
# 333531  -73.91954      (40.816555, -73.91954)                E 149 ST
# 359475  -73.99530       (40.749363, -73.9953)                     NaN
#
#              CROSS STREET NAME  OFF STREET NAME  ...  BoroCode   BoroName  \
# 104063                     NaN              NaN  ...       1.0  Manhattan
# 159410          EAST 42 STREET              NaN  ...       1.0  Manhattan
# 164818          WEST 36 STREET              NaN  ...       1.0  Manhattan
# 246692          JACKSON STREET              NaN  ...       1.0  Manhattan
# 290041  AVENUE OF THE AMERICAS              NaN  ...       1.0  Manhattan
# 333531          COURTLANDT AVE              NaN  ...       2.0      Bronx
# 359475                     NaN  400       8 AVE  ...       1.0  Manhattan
#
#            Shape_Leng    Shape_Area  Type code 1  \
# 104063  359536.412002  6.366312e+08          NaN
# 159410  359536.412002  6.366312e+08          NaN
# 164818  359536.412002  6.366312e+08          NaN
# 246692  359536.412002  6.366312e+08          NaN
# 290041  359536.412002  6.366312e+08          NaN
# 333531  463147.071763  1.187199e+09          NaN
# 359475  359536.412002  6.366312e+08          NaN
#
#                           Type code 1 lower  count vehicles  \
# 104063  station wagon/sport utility vehicle        119145.0
# 159410                                 taxi          9636.0
# 164818                                sedan        158471.0
# 246692                        pick-up truck          7921.0
# 290041                                 taxi          9636.0
# 333531                                sedan        158471.0
# 359475                                  van          2088.0
#
#                                    veh_type veh_group num_vehicles
# 104063  station wagon/sport utility vehicle       suv            1
# 159410                                 taxi      taxi            4
# 164818                                sedan     sedan            1
# 246692                        pick-up truck     truck            1
# 290041                                 taxi      taxi            1
# 333531                                sedan     sedan            1
# 359475                                  van       van            2
#
# [7 rows x 44 columns]

# %%
#  check total number of pedestrian injuries
df['NUMBER OF PEDESTRIANS INJURED'].sum()
# Out:
# np.int64(34477)

# %%
df[(df['NUMBER OF PEDESTRIANS INJURED'] >= 1) &
   (df['NUMBER OF PEDESTRIANS INJURED'] <= 5)].shape[0]
# Out:
# 33045

# %%
df['NUMBER OF PEDESTRIANS INJURED'].value_counts().sort_index()
# Out:
# NUMBER OF PEDESTRIANS INJURED
# 0     313363
# 1      31830
# 2       1091
# 3        100
# 4         17
# 5          7
# 6          1
# 7          3
# 8          2
# 19         1
# Name: count, dtype: int64

# %% [markdown]
# (Important: one crash can injure multiple pedestrians, so this sum is NOT the number of crashes.)
#
# 313,363 crashes had 0 pedestrians injured
#
# 31,380 crashes had 1 pedestrian injured
#
# 1,901 crashes had 2 pedestrians injured
#
# High-injury crashes (3, 4, 5, etc.) are rare and expected to be outliers

# %%
df[df['NUMBER OF PEDESTRIANS INJURED'] > 5][[
    'NUMBER OF PEDESTRIANS INJURED',
    'num_vehicles',
    'veh_group'
]]
# Out:
#         NUMBER OF PEDESTRIANS INJURED  num_vehicles veh_group
# 104063                             19             1       suv
# 159410                              8             4      taxi
# 164818                              7             1     sedan
# 246692                              7             1     truck
# 290041                              7             1      taxi
# 333531                              6             1     sedan
# 359475                              8             2       van

# %%
# now lets do pedestrian killed by vehicle type
df['NUMBER OF PEDESTRIANS KILLED'].describe()
# Out:
# count    346415.000000
# mean          0.001250
# std           0.036458
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           4.000000
# Name: NUMBER OF PEDESTRIANS KILLED, dtype: float64

# %%
# Count how many crashes had 0, 1, 2, etc. pedestrian fatalities
df['NUMBER OF PEDESTRIANS KILLED'].value_counts().sort_index()
# Out:
# NUMBER OF PEDESTRIANS KILLED
# 0    345992
# 1       416
# 2         5
# 3         1
# 4         1
# Name: count, dtype: int64

# %%
# show crashes only where pedestrians were killed
# df[df['NUMBER OF PEDESTRIANS KILLED'] > 0][[
#     'NUMBER OF PEDESTRIANS KILLED',
#     'NUMBER OF PERSONS INJURED',
#     'NUMBER OF PERSONS KILLED',
#     'num_vehicles',
#     'veh_type'
# ]]

# %%
df[df['NUMBER OF PEDESTRIANS KILLED'] > 3]
# Out:
#        CRASH DATE          CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 246692 2024-07-04 1900-01-01 20:52:00  MANHATTAN   10002.0  40.711533
#
#         LONGITUDE                    LOCATION ON STREET NAME  \
# 246692  -73.98063      (40.711533, -73.98063)   WATER STREET
#
#        CROSS STREET NAME OFF STREET NAME  ...  BoroCode   BoroName  \
# 246692    JACKSON STREET             NaN  ...       1.0  Manhattan
#
#            Shape_Leng    Shape_Area  Type code 1  Type code 1 lower  \
# 246692  359536.412002  6.366312e+08          NaN      pick-up truck
#
#         count vehicles       veh_type veh_group num_vehicles
# 246692          7921.0  pick-up truck     truck            1
#
# [1 rows x 44 columns]

# %% [markdown]
# Fatal pedestrian crashes are extremely rare (416 crashes where exactly one pedestrian died and 21 crashes where multiple pedestrians died (2, 3, or 4 deaths)). Vehicles involved in these events are often larger types such as trucks, vans, or SUVs, which aligns with higher risk due to vehicle mass and impact force.

# %%
df.shape, gdf.shape
# Out:
# ((346415, 44), (340858, 44))

# %%
df = gdf.copy()

# %%
# save cleaned data
df = gdf.drop(columns=['geometry'])
df.to_csv("../Data/clean/cleaned_crash_data.csv", index=False)
